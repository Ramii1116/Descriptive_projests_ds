# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_excel("P1-OfficeSupplies.xlsx")
df
# Out:
#     OrderDate   Region      Rep     Item  Units  Unit Price
# 0  2014-07-04     East  Richard  Pen Set     62        4.99
# 1  2014-07-12     East     Nick   Binder     29        1.99
# 2  2014-07-21  Central   Morgan  Pen Set     55       12.49
# 3  2014-07-29     East    Susan   Binder     81       19.99
# 4  2014-08-07  Central  Matthew  Pen Set     42       23.95
# 5  2014-08-15     East  Richard   Pencil     35        4.99
# 6  2014-08-24     West    James     Desk      3      275.00
# 7  2014-09-01  Central    Smith     Desk      2      125.00
# 8  2014-09-10  Central     Bill   Pencil      7        1.29
# 9  2014-09-18     East  Richard  Pen Set     16       15.99
# 10 2014-09-27     West    James      Pen     76        1.99
# 11 2014-10-05  Central   Morgan   Binder     28        8.99
# 12 2014-10-14     West   Thomas   Binder     57       19.99
# 13 2014-10-22     East  Richard      Pen     64        8.99
# 14 2014-10-31  Central   Rachel   Pencil     14        1.29
# ...

# %%
df.describe()
# Out:
#                  OrderDate      Units  Unit Price
# count                   43  43.000000   43.000000
# mean   2014-12-29 00:00:00  49.325581   20.308605
# min    2014-07-04 00:00:00   2.000000    1.290000
# 25%    2014-10-01 00:00:00  27.500000    3.990000
# 50%    2014-12-29 00:00:00  53.000000    4.990000
# 75%    2015-03-28 00:00:00  74.500000   17.990000
# max    2015-06-25 00:00:00  96.000000  275.000000
# std                    NaN  30.078248   47.345118

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 43 entries, 0 to 42
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   OrderDate   43 non-null     datetime64[ns]
#  1   Region      43 non-null     object
#  2   Rep         43 non-null     object
#  3   Item        43 non-null     object
#  4   Units       43 non-null     int64
#  5   Unit Price  43 non-null     float64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(3)
# memory usage: 2.1+ KB

# %%
df["Region"].unique()
# Out:
# array(['East', 'Central', 'West'], dtype=object)

# %%
df["Region"].value_counts()
# Out:
# Region
# Central    24
# East       13
# West        6
# Name: count, dtype: int64

# %%
sns.countplot(x=df["Region"]) # y axis takes count always
# Out:
# <Axes: xlabel='Region', ylabel='count'>

# %%
df["Rep"].value_counts()
# Out:
# Rep
# Richard    8
# Bill       5
# Alex       5
# Matthew    4
# James      4
# Rachel     4
# Morgan     3
# Susan      3
# Smith      3
# Nick       2
# Thomas     2
# Name: count, dtype: int64

# %%
df["Rep"].unique()
# Out:
# array(['Richard', 'Nick', 'Morgan', 'Susan', 'Matthew', 'James', 'Smith',
#        'Bill', 'Thomas', 'Rachel', 'Alex'], dtype=object)

# %%
df["Item"].value_counts()
# Out:
# Item
# Binder     15
# Pencil     13
# Pen Set     7
# Pen         5
# Desk        3
# Name: count, dtype: int64

# %%
df["Item"].unique()
# Out:
# array(['Pen Set', 'Binder', 'Pencil', 'Desk', 'Pen'], dtype=object)

# %%
df["Turnover"] = df["Units"] * df["Unit Price"]

# %%
df
# Out:
#     OrderDate   Region      Rep     Item  Units  Unit Price  Turnover
# 0  2014-07-04     East  Richard  Pen Set     62        4.99    309.38
# 1  2014-07-12     East     Nick   Binder     29        1.99     57.71
# 2  2014-07-21  Central   Morgan  Pen Set     55       12.49    686.95
# 3  2014-07-29     East    Susan   Binder     81       19.99   1619.19
# 4  2014-08-07  Central  Matthew  Pen Set     42       23.95   1005.90
# 5  2014-08-15     East  Richard   Pencil     35        4.99    174.65
# 6  2014-08-24     West    James     Desk      3      275.00    825.00
# 7  2014-09-01  Central    Smith     Desk      2      125.00    250.00
# 8  2014-09-10  Central     Bill   Pencil      7        1.29      9.03
# 9  2014-09-18     East  Richard  Pen Set     16       15.99    255.84
# 10 2014-09-27     West    James      Pen     76        1.99    151.24
# 11 2014-10-05  Central   Morgan   Binder     28        8.99    251.72
# ...

# %%
df.groupby("Rep")["Turnover"]

# %%
g=df.groupby("Rep")["Turnover"].sum().tolist()
# g.sort() .....?
